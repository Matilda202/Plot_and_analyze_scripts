# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_min = pd.read_excel('minimum_prediction_1323itr.xlsx', skiprows=1, header=None)
df_min
# Out:
#          0     1     2         3          4             5           6  \
# 0        1     0    30  4.028623  18.373323  1.234924e+00  158.824173
# 1        2     1    32  4.064525  17.295577  1.236500e+00  157.283342
# 2        3     2    34  4.025827  18.362579  2.468729e+00  181.367925
# 3        4     3    36  4.028215  19.327636  2.470000e+00  177.284572
# 4        5     4    38  3.970558  15.619241  2.470000e+00  180.664363
# ...    ...   ...   ...       ...        ...           ...         ...
# 1312  1313  2612  2652  3.772115  36.291449 -2.774651e-08   18.500186
# 1313  1314  2613  2654  3.984244  39.591004  2.469995e+00  194.508739
# 1314  1315  2614  2656  3.984282  39.591620  2.470000e+00  194.503333
# 1315  1316  2615  2658  3.984286  39.591894 -4.540683e-08  194.502313
# 1316  1317  2616  2660  3.984388  39.604908  1.273914e-08  194.471876
#
#              7         8
# 0    -0.689803  0.001180
# 1    -0.683525  0.000855
# 2    -0.678314  0.000196
# ...

# %%
itr = df_min[0]
data = df_min[2]
rho = df_min[3]
phi = df_min[4]
z = df_min[5]
gamma = df_min[6]
energy =df_min[7]

# %%
plt.figure(figsize=(10, 6))
plt.plot(data, energy)
plt.title('Global minimum predictions')
plt.xlabel('Data points')
plt.ylabel('Adsorption energy (eV)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data, energy)
plt.title('Global minimum predictions')
plt.xlabel('Data points')
plt.ylabel('Adsorption energy (eV)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(itr, energy)
plt.title('Global minimum predictions')
plt.xlabel('Iterations')
plt.ylabel('Adsorption energy (eV)')
plt.grid(True)
plt.show()

# %%
# Piirrä muuttujat scatter-muodossa
plt.figure(figsize=(10, 6))
plt.scatter(data, rho, label='rho', s=5)
plt.scatter(data, phi, label='phi', s=5)
plt.scatter(data, z, label='z', s=5)
plt.scatter(data, gamma, label='gamma', s=5)

# Asetukset
plt.xlabel('Data points')
plt.ylabel('Variable value')
plt.title('Global minimum predictions')
plt.grid(True)
plt.legend(loc='upper left')
plt.show()

# %%
# Piirrä muuttujat scatter-muodossa
plt.figure(figsize=(10, 6))
plt.scatter(data, rho, label='rho', s=5)
plt.scatter(data, z, label='z', s=5)

# Asetukset
plt.xlabel('Iterations')
plt.ylabel('Variable value')
plt.title('Global minimum predictions')
plt.grid(True)
plt.legend(loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(data, rho)
plt.xlabel('data points')
plt.ylabel('rho')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data, rho)
plt.xlabel('data points')
plt.ylabel('rho')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(data, phi)
plt.xlabel('data points')
plt.ylabel('phi')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data, phi)
plt.xlabel('data points')
plt.ylabel('phi')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(data, z)
plt.xlabel('data points')
plt.ylabel('z')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data, z)
plt.xlabel('data points')
plt.ylabel('z')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(data, gamma)
plt.xlabel('data points')
plt.ylabel('gamma')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data, gamma)
plt.xlabel('data points')
plt.ylabel('gamma')
plt.grid(True)
plt.show()

# %%
df_h = pd.read_excel('hyperparameters_1323itr.xlsx', skiprows=1, header=None)
df_h
# Out:
#          0     1     2         3         4         5         6         7
# 0        1     0    30  0.008625  0.668564  1.028621  1.875341  0.984539
# 1        2     1    32  0.008273  0.646391  1.025482  1.905576  0.982787
# 2        3     2    34  0.008762  0.658201  0.903920  1.873887  0.873597
# 3        4     3    36  0.008789  0.650130  0.958743  1.893436  0.878805
# 4        5     4    38  0.009790  0.684298  0.899471  1.787317  0.798250
# ...    ...   ...   ...       ...       ...       ...       ...       ...
# 1312  1313  2612  2652  0.011765  0.100781  0.630309  8.869605  0.132072
# 1313  1314  2613  2654  0.011710  0.041326  0.550746  9.156136  0.366797
# 1314  1315  2614  2656  0.011710  0.041376  0.550676  9.155975  0.366615
# 1315  1316  2615  2658  0.011710  0.041384  0.550702  9.155953  0.366678
# 1316  1317  2616  2660  0.011686  0.041513  0.550997  9.058145  0.366204
#
# [1317 rows x 8 columns]

# %%
plt.plot(df_h[2], df_h[4], label='L1', color='blue')
plt.plot(df_h[2], df_h[5], label='L2', color='orange')
plt.plot(df_h[2], df_h[6], label='L3', color='green')
plt.plot(df_h[2], df_h[7], label='L4', color='red')

plt.xlabel('Data points')
plt.title('Kernel lengthscale parameters')
plt.grid(visible=True)
plt.legend(loc='upper left')
plt.show()

# %%
plt.plot(df_h[2], df_h[4], label='L1', color='blue')
plt.plot(df_h[2], df_h[5], label='L2', color='orange')
plt.plot(df_h[2], df_h[7], label='L4', color='red')

plt.xlabel('data points')
plt.title('Kernel lengthscale parameters')
plt.grid(visible=True)
plt.legend(loc='upper left')
plt.show()

# %%
plt.scatter(df_h[2], df_h[4], label='L1')
plt.scatter(df_h[2], df_h[5], label='L2')
plt.scatter(df_h[2], df_h[6], label='L3')
plt.scatter(df_h[2], df_h[7], label='L4')

plt.xlabel('data points')
plt.title('Kernel lengthscale parameters')
plt.grid(visible=True)
plt.legend(loc='upper left')
plt.show()

# %%
def plot_l(iterations, value, title='Plot', ylabel='x'):
    plt.figure(figsize=(10, 6))
    plt.plot(iterations, value)  
    plt.yscale('log')             
    plt.ylabel(ylabel)
    plt.xlabel('data points')
    plt.grid(True)
    plt.show()


plot_l(df_h[2], df_h[3], title='hyperparameters variance', ylabel='variance')
plot_l(df_h[2], df_h[4], title='hyperparameters lengthscale', ylabel='lengthscale x1')
plot_l(df_h[2], df_h[5], title='hyperparameters lengthscale', ylabel='lengthscale x2')
plot_l(df_h[2], df_h[6], title='hyperparameters lengthscale', ylabel='lengthscale x3')
plot_l(df_h[2], df_h[7], title='hyperparameters lengthscale', ylabel='lengthscale x4')

# %%
def plot_l(iterations, value, title='Plot', ylabel='x'):
    plt.figure(figsize=(10, 6))
    plt.plot(iterations, value)              
    plt.ylabel(ylabel)
    plt.xlabel('data points')
    plt.grid(True)
    plt.title(title)
    plt.show()


plot_l(df_h[2], df_h[3], title='Kernel variance', ylabel='variance')

# %%
df_aq = pd.read_csv('postprocessing/acquisitions.dat', delim_whitespace=True, skiprows=1, header=None)
df_aq
# Out:
#            0       1         2          3         4           5         6
# 0        0.0     1.0  3.500000   0.000000  0.000000    0.000000 -0.382224
# 1        0.0     2.0  3.500000   0.000000  2.470000    0.000000 -0.382224
# 2        0.0     3.0  4.750000  30.000000  1.235000  180.000000 -0.457362
# 3        0.0     4.0  4.750000  30.000000  1.235000  180.000000 -0.457362
# 4        0.0     5.0  5.375000  15.000000  0.617500   90.000000 -0.229498
# ...      ...     ...       ...        ...       ...         ...       ...
# 2655  2614.0  2656.0  4.297915  19.169964  0.000140  355.537531 -0.631590
# 2656  2615.0  2657.0  5.448141  32.774285  0.000002  255.000206 -0.218891
# 2657  2615.0  2658.0  5.448141  32.774285  2.469998  255.000206 -0.218891
# 2658  2616.0  2659.0  4.617754   6.493100  2.470000   24.345871 -0.493059
# 2659  2616.0  2660.0  4.617754   6.493100  0.000000   24.345871 -0.493059
#
# [2660 rows x 7 columns]

# %%
data_points = df_aq[1]
rho = df_aq[2]
phi = df_aq[3]
z = df_aq[4]
gamma = df_aq[5]
energy = df_aq[6]

# %%
plt.figure(figsize=(10, 6))
plt.plot(data_points, rho, linestyle='None', marker='o')
plt.title('acquisition')
plt.xlabel('data points')
plt.ylabel('rho')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(data_points, phi, linestyle='None', marker='o')
plt.title('acquisition')
plt.xlabel('data points')
plt.ylabel('phi')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(data_points, z, linestyle='None', marker='o')
plt.title('acquisition')
plt.xlabel('data points')
plt.ylabel('z')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(data_points, gamma, linestyle='None', marker='o')
plt.title('acquisition')
plt.xlabel('data points')
plt.ylabel('gamma')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(data_points, gamma, linestyle='None', marker='o')
plt.title('acquisition')
plt.xlabel('data points')
plt.ylabel('gamma')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(data_points, energy, linestyle='None', marker='o')
plt.title('Acquisition locations with energy values')
plt.xlabel('data points')
plt.ylabel('energy (eV)')
plt.grid(True)
plt.show()
