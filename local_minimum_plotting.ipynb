# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data1000 = np.genfromtxt('it1015_npts1030.dat',
                     skip_header=0,
                     skip_footer=0,
                     names=None,
                     dtype=None,
                     delimiter=' ',
                     usecols=np.arange(0,6))

data1200 = np.genfromtxt('it1215_npts1230.dat',
                     skip_header=0,
                     skip_footer=0,
                     names=None,
                     dtype=None,
                     delimiter=' ',
                     usecols=np.arange(0,6))

data1400= np.genfromtxt('it1415_npts1430.dat',
                     skip_header=0,
                     skip_footer=0,
                     names=None,
                     dtype=None,
                     delimiter=' ',
                     usecols=np.arange(0,6))

data1600= np.genfromtxt('it1615_npts1630.dat',
                     skip_header=0,
                     skip_footer=0,
                     names=None,
                     dtype=None,
                     delimiter=' ',
                     usecols=np.arange(0,6))

data1800 = np.genfromtxt('it1815_npts1830.dat',
                     skip_header=0,
                     skip_footer=0,
                     names=None,
                     dtype=None,
                     delimiter=' ',
                     usecols=np.arange(0,6))

data2000 = np.genfromtxt('it2015_npts2030.dat',
                     skip_header=0,
                     skip_footer=0,
                     names=None,
                     dtype=None,
                     delimiter=' ',
                     usecols=np.arange(0,6))

data2200 = np.genfromtxt('it2215_npts2230.dat',
                     skip_header=0,
                     skip_footer=0,
                     names=None,
                     dtype=None,
                     delimiter=' ',
                     usecols=np.arange(0,6))

data2400 = np.genfromtxt('it2415_npts2430.dat',
                     skip_header=0,
                     skip_footer=0,
                     names=None,
                     dtype=None,
                     delimiter=' ',
                     usecols=np.arange(0,6))

data2600 = np.genfromtxt('it2601_npts2630.dat',
                     skip_header=0,
                     skip_footer=0,
                     names=None,
                     dtype=None,
                     delimiter=' ',
                     usecols=np.arange(0,6))

data2660 = np.genfromtxt('it2616_npts2660.dat',
                     skip_header=0,
                     skip_footer=0,
                     names=None,
                     dtype=None,
                     delimiter=' ',
                     usecols=np.arange(0,6))

# %%
minima1000 = range(0, 152)
minima1200 = range(0, 136)
minima1400 = range(0, 177)
minima1600 = range(0, 203)
minima1800 = range(0, 206)
minima2000 = range(0, 230)
minima2200 = range(0, 242)
minima2400 = range(0, 286)
minima2600 = range(0, 446)
minima2660 = range(0, 703)



energy1000 = data1000[:,4]
energy1200 = data1200[:,4]
energy1400 = data1400[:,4]
energy1600 = data1600[:,4]
energy1800 = data1800[:,4]
energy2000 = data2000[:,4]
energy2200 = data2200[:,4]
energy2400 = data2400[:,4]
energy2600 = data2600[:,4]
energy2660 = data2660[:,4]


# Pyplot multiple surrogate models
plt.plot(minima1000, energy1000, label="1000")
plt.plot(minima1200, energy1200, label="1200")
plt.plot(minima1400, energy1400, label="1400")
plt.plot(minima1600, energy1600, label="1600")
plt.plot(minima1800, energy1800, label="1800")
plt.plot(minima2000, energy2000, label="2000")
plt.plot(minima2200, energy2200, label="2200")
plt.plot(minima2400, energy2400, label="2400")
plt.plot(minima2600, energy2600, label="2600")
plt.plot(minima2660, energy2660, label="2630")
plt.xlabel('Local minima')
plt.ylabel('adsorption energy (eV)')
plt.title('4D search E2 + (6,6)')
plt.grid(visible=True)
plt.legend(loc='upper left')
plt.show()

# %%
plt.plot(minima1000, energy1000, label="1000")
plt.plot(minima1200, energy1200, label="1200")
plt.plot(minima1400, energy1400, label="1400")
plt.plot(minima1600, energy1600, label="1600")
plt.plot(minima1800, energy1800, label="1800")
plt.plot(minima2000, energy2000, label="2000")
plt.plot(minima2200, energy2200, label="2200")
plt.plot(minima2400, energy2400, label="2400")
plt.plot(minima2600, energy2600, label="2600")
plt.plot(minima2660, energy2660, label="2630")
plt.xlabel('Local minima')
plt.ylabel('adsorption energy (eV)')
plt.title('4D search E2 + (6,6)')
plt.ylim(-0.8, -0.7)
plt.xlim(-5, 200)
plt.grid(visible=True)
plt.legend(loc='lower right')
plt.show()

# %%
plt.plot(minima1000, energy1000, label="1000")
plt.plot(minima1200, energy1200, label="1200")
plt.plot(minima1400, energy1400, label="1400")
plt.plot(minima1600, energy1600, label="1600")
plt.plot(minima1800, energy1800, label="1800")
plt.plot(minima2000, energy2000, label="2000")
plt.plot(minima2200, energy2200, label="2200")
plt.plot(minima2400, energy2400, label="2400")
plt.plot(minima2600, energy2600, label="2600")
plt.plot(minima2660, energy2660, label="2630")
plt.xlabel('Local minima')
plt.ylabel('adsorption energy (eV)')
plt.title('4D search E2 + (6,6)')
plt.ylim(-0.795, -0.73)
plt.xlim(-5, 200)
plt.grid(visible=True)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# 2400: 3.908910046832296814e+00 4.475051780464983153e+01 2.151040011998913482e+00 2.081863363352682370e+02 -7.844517910907931046e-01
# tällöin kt:n kanssa (0.05) = -0.7844518 + 0.05 = -0.7344518 eV
#
# 2600: 3.772136993232106050e+00 3.629307144361822424e+01 2.470007443524946833e+00 3.784771907630618557e+02 -7.827579040111742881e-01
# tällöin kt:n kanssa (0.05) = -0.7827579 + 0.05 = -0.7327579 eV
#
# 2630: 3.984376054751272545e+00 3.960140779475490547e+01 -3.906960471399004912e-04 1.944873890083962067e+02 -7.925699016126418472e-01
# tällöin kt:n kanssa (0.05) = -0.792569902 + 0.05 = -0.742569902

# %%
plt.plot(minima1000, energy1000, label="1000")
plt.plot(minima1200, energy1200, label="1200")
plt.plot(minima1400, energy1400, label="1400")
plt.plot(minima1600, energy1600, label="1600")
plt.plot(minima1800, energy1800, label="1800")
plt.plot(minima2000, energy2000, label="2000")
plt.plot(minima2200, energy2200, label="2200")
plt.plot(minima2400, energy2400, label="2400")
plt.plot(minima2600, energy2600, label="2600")
plt.plot(minima2660, energy2660, label="2630")

# Add horizontal line
plt.axhline(y=-0.742569902, color='red', linestyle='--', label='kTx2')


plt.xlabel('Local minima')
plt.ylabel('Adsorption energy (eV)')
plt.title('4D search E2 + (6,6)')
plt.ylim(-0.795, -0.74)
plt.xlim(-5.00, 200)
plt.grid(visible=True)
plt.legend(loc='lower right')
plt.show()

# %%
plt.plot(minima1000, energy1000, label="1000")
plt.plot(minima1200, energy1200, label="1200")
plt.plot(minima1400, energy1400, label="1400")
plt.plot(minima1600, energy1600, label="1600")
plt.plot(minima1800, energy1800, label="1800")
plt.plot(minima2000, energy2000, label="2000")
plt.plot(minima2200, energy2200, label="2200")
plt.plot(minima2400, energy2400, label="2400")
plt.plot(minima2600, energy2600, label="2600")
plt.plot(minima2660, energy2660, label="2630")

# Add horizontal line
plt.axhline(y=-0.742569902, color='red', linestyle='--', label='kTx2')


plt.xlabel('Local minima')
plt.ylabel('Adsorption energy (eV)')
plt.title('4D search E2 + (6,6)')
plt.ylim(-0.795, -0.74)
plt.xlim(-5.00, 150)
plt.grid(visible=True)
plt.legend(loc='lower right')
plt.show()
