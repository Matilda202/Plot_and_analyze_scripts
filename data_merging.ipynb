# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel('minimum_prediction_1292itr.xlsx')
df
# Out:
#          0     1         2          3         4           5         6  \
# 0        0    30  4.028623  18.373323  1.234924  158.824173 -0.689803
# 1        1    32  4.064525  17.295577  1.236500  157.283342 -0.683525
# 2        2    34  4.025827  18.362579  2.468729  181.367925 -0.678314
# 3        3    36  4.028215  19.327636  2.470000  177.284572 -0.677197
# 4        4    38  3.970558  15.619241  2.470000  180.664363 -0.685544
# ...    ...   ...       ...        ...       ...         ...       ...
# 1282  2399  2592  3.873221  15.798087  1.235000  191.839387 -0.782379
# 1283  2400  2594  3.873321  15.798271  1.235007  191.841470 -0.782347
# 1284  2401  2596  3.959595  42.522971 -0.000009  183.549427 -0.781784
# 1285  2402  2598  3.959606  42.522974  2.470000  183.545903 -0.781801
# 1286  2403  2600  3.959633  42.522849  2.470000  183.539802 -0.781829
#
#              7
# 0     0.001180
# 1     0.000855
# 2     0.000196
# 3     0.000153
# 4     0.000324
# ...        ...
# ...

# %%
df_s = pd.read_csv('postprocessing/minimum_predictions.dat', delim_whitespace=True, skiprows=1, header=None)
df_s
# Out:
#          0       1         2          3             4           5         6  \
# 0   2587.0  2602.0  3.987144  41.933258  2.085531e+00  185.131091 -0.784803
# 1   2588.0  2604.0  3.987242  41.905997  2.085740e+00  185.135323 -0.784943
# 2   2589.0  2606.0  3.959768  42.523515 -1.700199e-11  183.489756 -0.782050
# 3   2590.0  2608.0  3.960138  42.522131  2.470000e+00  183.403216 -0.782454
# 4   2591.0  2610.0  3.960152  42.522081  2.470000e+00  183.399754 -0.782470
# 5   2592.0  2612.0  3.984351  39.644593  2.470000e+00  194.573810 -0.792456
# 6   2593.0  2614.0  3.775230  36.249490 -1.432055e-07   18.499076 -0.784417
# 7   2594.0  2616.0  3.775229  36.249515  7.784199e-12   18.498799 -0.784415
# 8   2595.0  2618.0  3.775229  36.249280 -2.807457e-10   18.498642 -0.784415
# 9   2596.0  2620.0  3.775221  36.249510  2.470000e+00   18.498116 -0.784409
# 10  2597.0  2622.0  3.775231  36.249442  2.470000e+00   18.500523 -0.784419
# ...

# %%
df_combined = pd.concat([df, df_s], ignore_index=True)
df_combined.to_excel('minimum_prediction_1323itr.xlsx')

# %%
df_hyp1 = pd.read_excel('hyperparameters_1292itr.xlsx')
df_hyp = pd.read_csv('postprocessing/hyperparameters.dat', delim_whitespace=True, skiprows=2, header=None)
df_hyp
# Out:
#          0       1         2         3         4          5         6
# 0      0.0    15.0  0.017230  0.555808  0.479267   0.800423  0.480930
# 1   2587.0  2602.0  0.012644  0.317357  1.060250   0.627991  0.133601
# 2   2588.0  2604.0  0.012661  0.318313  1.058089   0.626966  0.133622
# 3   2589.0  2606.0  0.017604  0.258187  0.104346  14.378192  0.410328
# 4   2590.0  2608.0  0.017526  0.255208  0.105086  14.378550  0.408912
# 5   2591.0  2610.0  0.017502  0.255087  0.105115  14.378782  0.408838
# 6   2592.0  2612.0  0.011696  0.041635  0.556315   8.902695  0.364154
# 7   2593.0  2614.0  0.011889  0.103461  0.625971   9.019766  0.130155
# 8   2594.0  2616.0  0.011878  0.103457  0.625841   9.019704  0.130167
# 9   2595.0  2618.0  0.011876  0.103465  0.625860   9.019697  0.130181
# 10  2596.0  2620.0  0.011858  0.103443  0.625536   9.019483  0.130229
# 11  2597.0  2622.0  0.011853  0.103484  0.625631   9.018956  0.130158
# ...

# %%
df_comb = pd.concat([df_hyp1, df_hyp], ignore_index=True)
df_comb.to_excel('hyperparameters_1323itr.xlsx')
